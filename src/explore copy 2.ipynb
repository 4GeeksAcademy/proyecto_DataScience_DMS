# %% [markdown]
# # Explore here

# %%
import requests
import pandas as pd

# URL 
url_fed = "https://api.stlouisfed.org/fred/series/observations?series_id&api_key&file_type"


# Parámetros de la solicitud
parametros_fed = {
    "series_id":"CPIAUCSL",
    "api_key":"16dbd1bdceb90ffd932425b7e5c279fd",  
    "file_type":"json" 
}

def api_fed(url, parametros, realtime_start, realtime_end):

# Añadir fechas de busqueda 
    parametros["realtime_start"] = realtime_start
    parametros["realtime_end"] = realtime_end


# Realizar la solicitud GET
    response = requests.get(url, params=parametros)

    print(url)

# Verificar si la solicitud fue exitosa
    if response.status_code == 200:
    # Convertir la respuesta a formato JSON
        data = response.json()
    # Retorna la data 
        return data
    else:
        print(f"Error en la solicitud: {response.status_code}")


data = api_fed(url_fed,parametros_fed, "2021-01-01", "2023-12-31")

data_CPIAUCSL = pd.DataFrame(data)

data_CPIAUCSL.head(2)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id&api_key&file_type
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc   1103       0  100000
# 1            1      json  observation_date        asc   1103       0  100000
#
#                                         observations
# 0  {'realtime_start': '2021-01-01', 'realtime_end...
# 1  {'realtime_start': '2021-01-01', 'realtime_end...

# %%
data_CPIAUCSL.columns
# Out:
# Index(['realtime_start', 'realtime_end', 'observation_start',
#        'observation_end', 'units', 'output_type', 'file_type', 'order_by',
#        'sort_order', 'count', 'offset', 'limit', 'observations'],
#       dtype='object')

# %%
def obtener_observation_fed(data_CPIAUCSL):
    # Convertir la columna "observations" que contiene JSON en un DataFrame
    observations_data = pd.json_normalize(data_CPIAUCSL["observations"])
    
    # Concatenar el DataFrame original con el nuevo DataFrame de las observaciones
    data_CPIAUCSL = pd.concat([data_CPIAUCSL.drop(columns=["observations"]), observations_data], axis=1)

    return data_CPIAUCSL

# Ejecutar la función para obtener los datos procesados
data_CPIAUCSL = obtener_observation_fed(data_CPIAUCSL)

def guardar_csv(data , url_archivo):
    data.to_csv(url_archivo, index= True)

# %%
#data_fed_cpi.head(10)
data_CPIAUCSL.tail(2)
# Out:
#      realtime_start realtime_end observation_start observation_end units  \
# 1101     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1102     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#       output_type file_type          order_by sort_order  count  offset  \
# 1101            1      json  observation_date        asc   1103       0
# 1102            1      json  observation_date        asc   1103       0
#
#        limit realtime_start realtime_end        date    value
# 1101  100000     2023-11-14   2023-12-31  2023-10-01  307.619
# 1102  100000     2023-12-12   2023-12-31  2023-11-01  307.917

# %%
guardar_csv(data_CPIAUCSL , "../data/raw/fed_CPIAUCSL_historical_data.csv")

# %% [markdown]
# Producto interno bruto='GNP"
# Api_key='b55d1a0787bb20a7fcc6aef921343008'

# %%
# URL 
url_fed = "https://api.stlouisfed.org/fred/series/observations?series_id&api_key&file_type"


# Parámetros de la solicitud
parametros_fed = {
    "series_id": "GNP",
    "api_key": "b55d1a0787bb20a7fcc6aef921343008",  
    "file_type": "json" 
}

data = api_fed(url_fed,parametros_fed, "2021-01-01", "2023-12-31")

data_GNP = pd.DataFrame(data)

data_GNP.head(2)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id&api_key&file_type
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc    512       0  100000
# 1            1      json  observation_date        asc    512       0  100000
#
#                                         observations
# 0  {'realtime_start': '2021-01-01', 'realtime_end...
# 1  {'realtime_start': '2021-01-01', 'realtime_end...

# %%
# Ejecutar la función para obtener los datos procesados
data_GNP = obtener_observation_fed(data_GNP)

# %%
#data_GNPCA.head(2)
data_GNP.tail(2)
# Out:
#     realtime_start realtime_end observation_start observation_end units  \
# 510     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 511     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#      output_type file_type          order_by sort_order  count  offset  \
# 510            1      json  observation_date        asc    512       0
# 511            1      json  observation_date        asc    512       0
#
#       limit realtime_start realtime_end        date      value
# 510  100000     2023-11-29   2023-12-20  2023-07-01  27812.417
# 511  100000     2023-12-21   2023-12-31  2023-07-01  27774.189

# %%
guardar_csv(data_GNP,"../data/raw/fed_GNP_historical_data.csv")

# %% [markdown]
# Tasa de desempleo='UNRATE'
# Api_key='8660234b709531d44271bbd9520353dd'

# %%
# URL 
url_fed = "https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id"


# Parámetros de la solicitud
parametros_fed = {
    "api_key": "8660234b709531d44271bbd9520353dd",  
    "file_type": "json",
    "series_id": "UNRATE"
}

data = api_fed(url_fed,parametros_fed, "2021-01-01", "2023-12-31")

data_UNRATE = pd.DataFrame(data)

data_UNRATE.head(2)
# Out:
# https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc    945       0  100000
# 1            1      json  observation_date        asc    945       0  100000
#
#                                         observations
# 0  {'realtime_start': '2021-01-01', 'realtime_end...
# 1  {'realtime_start': '2021-01-01', 'realtime_end...

# %%
# Ejecutar la función para obtener los datos procesados
data_UNRATE = obtener_observation_fed(data_UNRATE)

# %%
data_UNRATE.tail(2)
# Out:
#     realtime_start realtime_end observation_start observation_end units  \
# 943     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 944     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#      output_type file_type          order_by sort_order  count  offset  \
# 943            1      json  observation_date        asc    945       0
# 944            1      json  observation_date        asc    945       0
#
#       limit realtime_start realtime_end        date value
# 943  100000     2023-11-03   2023-12-31  2023-10-01   3.9
# 944  100000     2023-12-08   2023-12-31  2023-11-01   3.7

# %%
guardar_csv(data_UNRATE,"../data/raw/fed_UNRATE_historical_data.csv")

# %% [markdown]
# Federal Funds Effective Rate (DFF)
# Tasa de interes='DFF'
# Api_key='78f1d1b71351546a936232d4d5469d80'

# %%
# URL 
url_fed = "https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id"


# Parámetros de la solicitud
parametros_fed = {
    "api_key": "78f1d1b71351546a936232d4d5469d80",  
    "file_type": "json",
    "series_id": "DFF"
}

data = api_fed(url_fed,parametros_fed, "2021-01-01", "2023-12-31")

data_DFF= pd.DataFrame(data)

data_DFF.head(2)
# Out:
# https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc  25383       0  100000
# 1            1      json  observation_date        asc  25383       0  100000
#
#                                         observations
# 0  {'realtime_start': '2021-01-01', 'realtime_end...
# 1  {'realtime_start': '2021-01-01', 'realtime_end...

# %%
# Ejecutar la función para obtener los datos procesados
data_DFF = obtener_observation_fed(data_DFF)

# %%
data_DFF.tail(2)
# Out:
#       realtime_start realtime_end observation_start observation_end units  \
# 25381     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 25382     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#        output_type file_type          order_by sort_order  count  offset  \
# 25381            1      json  observation_date        asc  25383       0
# 25382            1      json  observation_date        asc  25383       0
#
#         limit realtime_start realtime_end        date value
# 25381  100000     2023-12-28   2023-12-31  2023-12-27  5.33
# 25382  100000     2023-12-29   2023-12-31  2023-12-28  5.33

# %%
guardar_csv(data_DFF,"../data/raw/fed_DFF_historical_data.csv")

# %% [markdown]
# Trade Balance: Goods and Services, Balance of Payments Basis (BOPGSTB)
# Tasa de interes='BOPGSTB'
# Api_key='58f82a464f9ab2bc239793f7ebb937f7'

# %%
# URL 
url_fed = "https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id"


# Parámetros de la solicitud
parametros_fed = {
    "api_key": "58f82a464f9ab2bc239793f7ebb937f7",  
    "file_type": "json",
    "series_id": "BOPGSTB"
}

data = api_fed(url_fed,parametros_fed, "2021-01-01", "2023-12-31")

data_BOPGSTB= pd.DataFrame(data)

data_BOPGSTB.head(2)
# Out:
# https://api.stlouisfed.org/fred/series/observations?api_key&file_type&series_id
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 1     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc    769       0  100000
# 1            1      json  observation_date        asc    769       0  100000
#
#                                         observations
# 0  {'realtime_start': '2021-01-01', 'realtime_end...
# 1  {'realtime_start': '2021-01-01', 'realtime_end...

# %%
# Ejecutar la función para obtener los datos procesados
data_BOPGSTB = obtener_observation_fed(data_BOPGSTB)

# %%
data_BOPGSTB.tail(5)
# Out:
#     realtime_start realtime_end observation_start observation_end units  \
# 764     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 765     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 766     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 767     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
# 768     2021-01-01   2023-12-31        1600-01-01      9999-12-31   lin
#
#      output_type file_type          order_by sort_order  count  offset  \
# 764            1      json  observation_date        asc    769       0
# 765            1      json  observation_date        asc    769       0
# 766            1      json  observation_date        asc    769       0
# 767            1      json  observation_date        asc    769       0
# 768            1      json  observation_date        asc    769       0
#
#       limit realtime_start realtime_end        date     value
# 764  100000     2023-11-07   2023-12-05  2023-08-01  -58657.0
# 765  100000     2023-12-06   2023-12-31  2023-08-01  -58624.0
# 766  100000     2023-11-07   2023-12-05  2023-09-01  -61542.0
# 767  100000     2023-12-06   2023-12-31  2023-09-01  -61151.0
# 768  100000     2023-12-06   2023-12-31  2023-10-01  -64255.0

# %%
guardar_csv(data_BOPGSTB,"../data/raw/fed_BOPGSTB_historical_data.csv")

# %% [markdown]
# Seleccionar solo las columnas de 'date' y 'value, agregar una más con el nombre de la variable

# %%
df_CPIAUCSL = data_CPIAUCSL[['date','value']].copy()
df_CPIAUCSL['date'] = pd.to_datetime(df_CPIAUCSL['date'])
df_CPIAUCSL['value'] = pd.to_numeric(df_CPIAUCSL['value'], errors='coerce')
df_CPIAUCSL['value'] = df_CPIAUCSL['value'].apply(lambda x: x*1000 if x < 500 else x)
df_CPIAUCSL['IPC_value'] = df_CPIAUCSL['value']
df_CPIAUCSL = df_CPIAUCSL.drop('value', axis=1)
df_CPIAUCSL = df_CPIAUCSL.drop_duplicates(subset=['date'], keep='last')
df_CPIAUCSL.set_index('date', inplace=True)

# Cambiar la frecuencia a diaria y rellenar con NaN
df_IPC_D = df_CPIAUCSL.resample('D').asfreq()

# Función personalizada para interpolar el valor y calcular variación diaria
def interpolar_valor(df_CPIAUCSL):
    # Interpolar valores entre meses
    df_interpolado = df_CPIAUCSL.resample('D').interpolate(method='linear')
    
    # Calcular la variación diaria como porcentaje
    df_interpolado['IPC_var'] = df_interpolado['IPC_value'].pct_change().round(5) * 100
    
    return df_interpolado

# Aplicar la función a los datos diarios
df_IPC_D = interpolar_valor(df_CPIAUCSL)

#df_IPC_D = df_IPC_D[(df_IPC_D['date'] >= '2021-01-01') & (df_IPC_D['date'] <= '2023-12-31')]
df_IPC_D
# Out:
#                 IPC_value  IPC_var
# date
# 1947-01-01   21480.000000      NaN
# 1947-01-02   21484.516129    0.021
# 1947-01-03   21489.032258    0.021
# 1947-01-04   21493.548387    0.021
# 1947-01-05   21498.064516    0.021
# ...                   ...      ...
# 2023-10-28  307878.548387    0.003
# 2023-10-29  307888.161290    0.003
# 2023-10-30  307897.774194    0.003
# 2023-10-31  307907.387097    0.003
# 2023-11-01  307917.000000    0.003
#
# [28064 rows x 2 columns]

# %%
df_BOPGSTBL = data_BOPGSTB[['date','value']].copy()
df_BOPGSTBL['date'] = pd.to_datetime(df_BOPGSTBL['date'])
df_BOPGSTBL['value'] = pd.to_numeric(df_BOPGSTBL['value'], errors='coerce')
df_BOPGSTBL['BC_value'] = df_BOPGSTBL['value'].apply(lambda x: x/100000000000 if x < -200000 else x)
df_BOPGSTBL = df_BOPGSTBL.drop('value', axis=1)
df_BOPGSTBL = df_BOPGSTBL.drop_duplicates(subset=['date'], keep='last')
df_BOPGSTBL.set_index('date', inplace=True)

df_BC_D = df_BOPGSTBL.resample('D').asfreq()
df_BC_D = df_BC_D.resample('D').interpolate(method='linear')
df_BC_D['BC_var'] = df_BC_D['BC_value'].pct_change().round(5) * 100
 
df_BC_D
# Out:
#                 BC_value  BC_var
# date
# 1992-01-01  -2026.000000     NaN
# 1992-01-02  -1987.451613  -1.903
# 1992-01-03  -1948.903226  -1.940
# 1992-01-04  -1910.354839  -1.978
# 1992-01-05  -1871.806452  -2.018
# ...                  ...     ...
# 2023-09-27 -63841.133333   0.162
# 2023-09-28 -63944.600000   0.162
# 2023-09-29 -64048.066667   0.162
# 2023-09-30 -64151.533333   0.162
# 2023-10-01 -64255.000000   0.161
#
# [11597 rows x 2 columns]

# %%
df_DFF = data_DFF[['date','value']].copy()

df_DFF['date'] = pd.to_datetime(df_DFF['date'])
df_DFF['value'] = pd.to_numeric(df_DFF['value'], errors='coerce')
df_DFF['TPM_value'] = df_DFF['value']
df_DFF['TPM_var'] = df_DFF['value'].pct_change().round(5) * 100
df_DFF = df_DFF.drop('value', axis=1)
df_DFF = df_DFF.drop_duplicates(subset=['date'], keep='last')
df_DFF.set_index('date', inplace=True)

df_DFF
# Out:
#             TPM_value  TPM_var
# date
# 1954-07-01       1.13      NaN
# 1954-07-02       1.25   10.619
# 1954-07-03       1.25    0.000
# 1954-07-04       1.25    0.000
# 1954-07-05       0.88  -29.600
# ...               ...      ...
# 2023-12-24       5.33    0.000
# 2023-12-25       5.33    0.000
# 2023-12-26       5.33    0.000
# 2023-12-27       5.33    0.000
# 2023-12-28       5.33    0.000
#
# [25383 rows x 2 columns]

# %%
df_GNP = data_GNP[['date','value']].copy()
df_GNP['date'] = pd.to_datetime(df_GNP['date'])
df_GNP['value'] = pd.to_numeric(df_GNP['value'], errors='coerce')
df_GNP['PIB_value'] = df_GNP['value'].apply(lambda x: x*1000 if x < 30000 else x)
df_GNP = df_GNP.drop('value', axis=1)
df_GNP = df_GNP.drop_duplicates(subset=['date'], keep='last')
df_GNP.set_index('date', inplace=True)

df_PIB_D = df_GNP.resample('D').asfreq()
df_PIB_D = df_PIB_D.resample('D').interpolate(method='linear')
df_PIB_D['PIB_var'] = df_PIB_D['PIB_value'].pct_change().round(5) * 100

df_PIB_D
# Out:
#                PIB_value  PIB_var
# date
# 1939-01-01           NaN      NaN
# 1939-01-02           NaN      NaN
# 1939-01-03           NaN      NaN
# 1939-01-04           NaN      NaN
# 1939-01-05           NaN      NaN
# ...                  ...      ...
# 2023-06-27  2.775054e+07    0.021
# 2023-06-28  2.775645e+07    0.021
# 2023-06-29  2.776236e+07    0.021
# 2023-06-30  2.776828e+07    0.021
# 2023-07-01  2.777419e+07    0.021
#
# [30863 rows x 2 columns]

# %%
df_UNRATE = data_UNRATE[['date','value']].copy()
df_UNRATE['date'] = pd.to_datetime(df_UNRATE['date'])
df_UNRATE['value'] = pd.to_numeric(df_UNRATE['value'], errors='coerce')
df_UNRATE['TDES_value'] = df_UNRATE['value']
df_UNRATE = df_UNRATE.drop('value', axis=1)
df_UNRATE = df_UNRATE.drop_duplicates(subset=['date'], keep='last')
df_UNRATE.set_index('date', inplace=True)
df_TDES_D = df_UNRATE.resample('D').asfreq()
df_TDES_D = df_TDES_D.resample('D').interpolate(method='linear')
df_TDES_D['TDES_var'] = df_TDES_D['TDES_value'].pct_change().round(5) * 100

df_TDES_D
# Out:
#             TDES_value  TDES_var
# date
# 1948-01-01    3.400000       NaN
# 1948-01-02    3.412903     0.380
# 1948-01-03    3.425806     0.378
# 1948-01-04    3.438710     0.377
# 1948-01-05    3.451613     0.375
# ...                ...       ...
# 2023-10-28    3.725806    -0.173
# 2023-10-29    3.719355    -0.173
# 2023-10-30    3.712903    -0.173
# 2023-10-31    3.706452    -0.174
# 2023-11-01    3.700000    -0.174
#
# [27699 rows x 2 columns]

# %% [markdown]
# Guardar df's en carpeta processed, tienen solo las columnas valor, date y nombre

# %%
guardar_csv(df_BC_D,"../data/processed/df_balanzacomercial_diario.csv")
guardar_csv(df_IPC_D,"../data/processed/df_indicepreciosconsumidor_diario.csv")
guardar_csv(df_DFF,"../data/processed/df_tasainteres_diario.csv")
guardar_csv(df_PIB_D,"../data/processed/df_productointernobruto_diario.csv")
guardar_csv(df_TDES_D,"../data/processed/df_tasadesempleo_diario.csv")

# %% [markdown]
# Consolidar los df's en uno solo, porque comparten las mismas columnas

# %% [markdown]
# Guardar dataframe consolidado

# %% [markdown]
# ### Valor de los activos

# %%
import requests
import csv
import json
from datetime import datetime, timedelta

# API Key de Polygon.io
key_activos = '2T0PMe4qTXopT2r7lymhHfrBvMNhx6VI'

# Símbolos de los activos
activos = {      
    'VTI': 'VTI',          
    'Oro': 'C:XAUUSD',       
    'Bitcoin': 'X:BTCUSD'    
}

# Función para consultar datos históricos de un activo
def api_activos(key_activos, activo, timespan='day', start_date=None, end_date=None):
    # URL de la API para obtener los datos históricos
    url = f'https://api.polygon.io/v2/aggs/ticker/{activo}/range/1/{timespan}/{start_date}/{end_date}?adjusted=true&sort=asc&apiKey={key_activos}'
    
    # Hacer la solicitud GET a la API de Polygon.io
    response = requests.get(url)
    print(url)

    # Verificar si la solicitud fue exitosa
    if response.status_code == 200:
        # Convertir la respuesta a formato JSON
        data = response.json()
        print ("bien")

        if 'results' in data:
            return data['results']  # Devolver solo los resultados
        else:
            print("No se encontraron resultados en la respuesta.")
            return []
    else:
        print(f"Error en la solicitud: {response.status_code}")
        return []


# Llamar a la función para cada activo y guardar los datos en archivos CSV separados

# Obtener y guardar datos del VTI
historical_data_vti = api_activos(key_activos, activos['VTI'], 'day', "2021-01-01", "2023-12-31")
vti = pd.DataFrame(historical_data_vti)
guardar_csv(vti, '../data/VTI_historical_data.csv')
# Out:
# https://api.polygon.io/v2/aggs/ticker/VTI/range/1/day/2021-01-01/2023-12-31?adjusted=true&sort=asc&apiKey=2T0PMe4qTXopT2r7lymhHfrBvMNhx6VI
# bien

# %%
# convertir a fecha 

vti['t'] = pd.to_datetime(vti['t'], unit='ms').dt.strftime('%Y-%m-%d')
vti
# Out:
#               v        vw         o       c         h         l           t  \
# 0     4847493.0  191.5279  191.2500  191.66  193.3100  189.4200  2022-11-08
# 1    13958461.0  187.9277  190.4600  187.53  191.0400  187.2100  2022-11-09
# 2     3981594.0  196.1325  194.3500  198.14  198.3100  193.6500  2022-11-10
# 3     4550171.0  199.1410  198.5800  200.16  200.7000  197.8200  2022-11-11
# 4     4248218.0  199.7847  199.2600  198.35  200.9200  198.2100  2022-11-14
# ..          ...       ...       ...     ...       ...       ...         ...
# 282   3662383.0  236.8428  236.5896  236.63  237.5150  235.6400  2023-12-22
# 283   3829400.0  237.5316  236.9800  237.80  238.3100  236.8559  2023-12-26
# 284   5103732.0  237.9578  238.0000  238.25  238.4400  237.4700  2023-12-27
# 285   4099416.0  238.4654  238.2500  238.13  238.7399  238.1300  2023-12-28
# 286   4188762.0  237.4897  238.1400  237.22  238.4700  236.4800  2023-12-29
#
#          n
# 0    56959
# 1    70496
# 2    63249
# 3    55987
# 4    72199
# ..     ...
# 282  60667
# 283  59244
# 284  62196
# 285  78091
# 286  71842
#
# [287 rows x 8 columns]

# %%
# Nueva columna con el valor de cierre del día anterior
vti['cierre_anterior'] = vti['c'].shift(1)

vti
# Out:
#               v        vw         o       c         h         l           t  \
# 0     4847493.0  191.5279  191.2500  191.66  193.3100  189.4200  2022-11-08
# 1    13958461.0  187.9277  190.4600  187.53  191.0400  187.2100  2022-11-09
# 2     3981594.0  196.1325  194.3500  198.14  198.3100  193.6500  2022-11-10
# 3     4550171.0  199.1410  198.5800  200.16  200.7000  197.8200  2022-11-11
# 4     4248218.0  199.7847  199.2600  198.35  200.9200  198.2100  2022-11-14
# ..          ...       ...       ...     ...       ...       ...         ...
# 282   3662383.0  236.8428  236.5896  236.63  237.5150  235.6400  2023-12-22
# 283   3829400.0  237.5316  236.9800  237.80  238.3100  236.8559  2023-12-26
# 284   5103732.0  237.9578  238.0000  238.25  238.4400  237.4700  2023-12-27
# 285   4099416.0  238.4654  238.2500  238.13  238.7399  238.1300  2023-12-28
# 286   4188762.0  237.4897  238.1400  237.22  238.4700  236.4800  2023-12-29
#
#          n  cierre_anterior
# 0    56959              NaN
# 1    70496           191.66
# 2    63249           187.53
# 3    55987           198.14
# 4    72199           200.16
# ..     ...              ...
# 282  60667           236.09
# 283  59244           236.63
# 284  62196           237.80
# 285  78091           238.25
# 286  71842           238.13
#
# [287 rows x 9 columns]

# %%
vti.drop(['v', 'vw', 'o', 'h', 'l', 'n'], axis = 1, inplace = True)

# %%
vti
# Out:
#           c           t  cierre_anterior
# 0    191.66  2022-11-08              NaN
# 1    187.53  2022-11-09           191.66
# 2    198.14  2022-11-10           187.53
# 3    200.16  2022-11-11           198.14
# 4    198.35  2022-11-14           200.16
# ..      ...         ...              ...
# 282  236.63  2023-12-22           236.09
# 283  237.80  2023-12-26           236.63
# 284  238.25  2023-12-27           237.80
# 285  238.13  2023-12-28           238.25
# 286  237.22  2023-12-29           238.13
#
# [287 rows x 3 columns]

# %%
# Calcular el cambio porcentual de 1, 5 y 10 días para cada activo incorporado
vti['pct_change_1d'] = vti['c'].pct_change(1) * 100
vti['pct_change_5d'] = vti['c'].pct_change(5) * 100
vti['pct_change_10d'] = vti['c'].pct_change(10) * 100

# %%
vti
# Out:
#           c           t  cierre_anterior  pct_change_1d  pct_change_5d  \
# 0    191.66  2022-11-08              NaN            NaN            NaN
# 1    187.53  2022-11-09           191.66      -2.154858            NaN
# 2    198.14  2022-11-10           187.53       5.657761            NaN
# 3    200.16  2022-11-11           198.14       1.019481            NaN
# 4    198.35  2022-11-14           200.16      -0.904277            NaN
# ..      ...         ...              ...            ...            ...
# 282  236.63  2023-12-22           236.09       0.228726       0.560962
# 283  237.80  2023-12-26           236.63       0.494443       0.622012
# 284  238.25  2023-12-27           237.80       0.189235       0.079812
# 285  238.13  2023-12-28           238.25      -0.050367       1.543644
# 286  237.22  2023-12-29           238.13      -0.382144       0.478631
#
#      pct_change_10d
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 282        3.399607
# 283        3.485791
# 284        3.290558
# 285        1.660690
# 286        0.674787
#
# [287 rows x 6 columns]

# %%
vti = vti.rename(columns = {'c' : 'VTI_value'})
vti = vti.rename(columns = {'t' : 'date'})

# %%
vti = vti.set_index("date")

vti
# Out:
#             VTI_value  cierre_anterior  pct_change_1d  pct_change_5d  \
# date
# 2022-11-08     191.66              NaN            NaN            NaN
# 2022-11-09     187.53           191.66      -2.154858            NaN
# 2022-11-10     198.14           187.53       5.657761            NaN
# 2022-11-11     200.16           198.14       1.019481            NaN
# 2022-11-14     198.35           200.16      -0.904277            NaN
# ...               ...              ...            ...            ...
# 2023-12-22     236.63           236.09       0.228726       0.560962
# 2023-12-26     237.80           236.63       0.494443       0.622012
# 2023-12-27     238.25           237.80       0.189235       0.079812
# 2023-12-28     238.13           238.25      -0.050367       1.543644
# 2023-12-29     237.22           238.13      -0.382144       0.478631
#
#             pct_change_10d
# date
# 2022-11-08             NaN
# 2022-11-09             NaN
# 2022-11-10             NaN
# 2022-11-11             NaN
# 2022-11-14             NaN
# ...                    ...
# 2023-12-22        3.399607
# 2023-12-26        3.485791
# 2023-12-27        3.290558
# 2023-12-28        1.660690
# 2023-12-29        0.674787
#
# [287 rows x 5 columns]

# %%
# Crear un rango de fechas para el índice
fecha_inicio = '2022-11-08'
fecha_fin = '2023-12-31'

rango_fechas = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='D')


# Crear el DataFrame base con el índice de fechas
df_indicadores_D = pd.DataFrame(index=rango_fechas)

# Llenar el DataFrame base con datos de otros DataFrames
df_indicadores_D = df_indicadores_D.join(df_DFF, how='left')
df_indicadores_D = df_indicadores_D.join(df_TDES_D, how='left')
df_indicadores_D = df_indicadores_D.join(df_IPC_D, how='left')
df_indicadores_D = df_indicadores_D.join(df_PIB_D, how='left')
df_indicadores_D = df_indicadores_D.join(df_BC_D, how='left')


df_indicadores_D
# Out:
#             TPM_value  TPM_var  TDES_value  TDES_var      IPC_value  IPC_var  \
# 2022-11-08       3.83      0.0    3.576667    -0.093  298689.466667    0.004
# 2022-11-09       3.83      0.0    3.573333    -0.093  298702.533333    0.004
# 2022-11-10       3.83      0.0    3.570000    -0.093  298715.600000    0.004
# 2022-11-11       3.83      0.0    3.566667    -0.093  298728.666667    0.004
# 2022-11-12       3.83      0.0    3.563333    -0.093  298741.733333    0.004
# ...               ...      ...         ...       ...            ...      ...
# 2023-12-27       5.33      0.0         NaN       NaN            NaN      NaN
# 2023-12-28       5.33      0.0         NaN       NaN            NaN      NaN
# 2023-12-29        NaN      NaN         NaN       NaN            NaN      NaN
# 2023-12-30        NaN      NaN         NaN       NaN            NaN      NaN
# 2023-12-31        NaN      NaN         NaN       NaN            NaN      NaN
#
#                PIB_value  PIB_var      BC_value  BC_var
# 2022-11-08  2.675035e+07    0.015 -65583.866667   0.386
# 2022-11-09  2.675446e+07    0.015 -65836.133333   0.385
# 2022-11-10  2.675858e+07    0.015 -66088.400000   0.383
# 2022-11-11  2.676269e+07    0.015 -66340.666667   0.382
# 2022-11-12  2.676681e+07    0.015 -66592.933333   0.380
# ...                  ...      ...           ...     ...
# 2023-12-27           NaN      NaN           NaN     NaN
# 2023-12-28           NaN      NaN           NaN     NaN
# 2023-12-29           NaN      NaN           NaN     NaN
# 2023-12-30           NaN      NaN           NaN     NaN
# 2023-12-31           NaN      NaN           NaN     NaN
#
# [419 rows x 10 columns]

# %%
df_indicadores_D.index= pd.to_datetime(df_indicadores_D.index, unit='ms').strftime('%Y-%m-%d')

# %%
df_indicadores_D = df_indicadores_D.join(vti, how = 'left')

df_indicadores_D
# Out:
#             TPM_value  TPM_var  TDES_value  TDES_var      IPC_value  IPC_var  \
# 2022-11-08       3.83      0.0    3.576667    -0.093  298689.466667    0.004
# 2022-11-09       3.83      0.0    3.573333    -0.093  298702.533333    0.004
# 2022-11-10       3.83      0.0    3.570000    -0.093  298715.600000    0.004
# 2022-11-11       3.83      0.0    3.566667    -0.093  298728.666667    0.004
# 2022-11-12       3.83      0.0    3.563333    -0.093  298741.733333    0.004
# ...               ...      ...         ...       ...            ...      ...
# 2023-12-27       5.33      0.0         NaN       NaN            NaN      NaN
# 2023-12-28       5.33      0.0         NaN       NaN            NaN      NaN
# 2023-12-29        NaN      NaN         NaN       NaN            NaN      NaN
# 2023-12-30        NaN      NaN         NaN       NaN            NaN      NaN
# 2023-12-31        NaN      NaN         NaN       NaN            NaN      NaN
#
#                PIB_value  PIB_var      BC_value  BC_var  VTI_value  \
# 2022-11-08  2.675035e+07    0.015 -65583.866667   0.386     191.66
# 2022-11-09  2.675446e+07    0.015 -65836.133333   0.385     187.53
# 2022-11-10  2.675858e+07    0.015 -66088.400000   0.383     198.14
# 2022-11-11  2.676269e+07    0.015 -66340.666667   0.382     200.16
# 2022-11-12  2.676681e+07    0.015 -66592.933333   0.380        NaN
# ...                  ...      ...           ...     ...        ...
# 2023-12-27           NaN      NaN           NaN     NaN     238.25
# 2023-12-28           NaN      NaN           NaN     NaN     238.13
# 2023-12-29           NaN      NaN           NaN     NaN     237.22
# 2023-12-30           NaN      NaN           NaN     NaN        NaN
# 2023-12-31           NaN      NaN           NaN     NaN        NaN
#
#             cierre_anterior  pct_change_1d  pct_change_5d  pct_change_10d
# 2022-11-08              NaN            NaN            NaN             NaN
# 2022-11-09           191.66      -2.154858            NaN             NaN
# 2022-11-10           187.53       5.657761            NaN             NaN
# 2022-11-11           198.14       1.019481            NaN             NaN
# 2022-11-12              NaN            NaN            NaN             NaN
# ...                     ...            ...            ...             ...
# 2023-12-27           237.80       0.189235       0.079812        3.290558
# 2023-12-28           238.25      -0.050367       1.543644        1.660690
# 2023-12-29           238.13      -0.382144       0.478631        0.674787
# 2023-12-30              NaN            NaN            NaN             NaN
# 2023-12-31              NaN            NaN            NaN             NaN
#
# [419 rows x 15 columns]

# %%
#incorporado las dos variables 5 y 10 dias
df_indicadores_D = df_indicadores_D [['VTI_value', 'cierre_anterior', 'pct_change_1d','pct_change_5d','pct_change_10d', 'TPM_value', 'TPM_var','TDES_value', 'TDES_var', 'IPC_value', 'IPC_var', 'PIB_value', 'PIB_var', 'BC_value', 'BC_var']]

df_indicadores_D
# Out:
#             VTI_value  cierre_anterior  pct_change_1d  pct_change_5d  \
# 2022-11-08     191.66              NaN            NaN            NaN
# 2022-11-09     187.53           191.66      -2.154858            NaN
# 2022-11-10     198.14           187.53       5.657761            NaN
# 2022-11-11     200.16           198.14       1.019481            NaN
# 2022-11-12        NaN              NaN            NaN            NaN
# ...               ...              ...            ...            ...
# 2023-12-27     238.25           237.80       0.189235       0.079812
# 2023-12-28     238.13           238.25      -0.050367       1.543644
# 2023-12-29     237.22           238.13      -0.382144       0.478631
# 2023-12-30        NaN              NaN            NaN            NaN
# 2023-12-31        NaN              NaN            NaN            NaN
#
#             pct_change_10d  TPM_value  TPM_var  TDES_value  TDES_var  \
# 2022-11-08             NaN       3.83      0.0    3.576667    -0.093
# 2022-11-09             NaN       3.83      0.0    3.573333    -0.093
# 2022-11-10             NaN       3.83      0.0    3.570000    -0.093
# 2022-11-11             NaN       3.83      0.0    3.566667    -0.093
# 2022-11-12             NaN       3.83      0.0    3.563333    -0.093
# ...                    ...        ...      ...         ...       ...
# 2023-12-27        3.290558       5.33      0.0         NaN       NaN
# 2023-12-28        1.660690       5.33      0.0         NaN       NaN
# 2023-12-29        0.674787        NaN      NaN         NaN       NaN
# 2023-12-30             NaN        NaN      NaN         NaN       NaN
# 2023-12-31             NaN        NaN      NaN         NaN       NaN
#
#                 IPC_value  IPC_var     PIB_value  PIB_var      BC_value  \
# 2022-11-08  298689.466667    0.004  2.675035e+07    0.015 -65583.866667
# 2022-11-09  298702.533333    0.004  2.675446e+07    0.015 -65836.133333
# 2022-11-10  298715.600000    0.004  2.675858e+07    0.015 -66088.400000
# 2022-11-11  298728.666667    0.004  2.676269e+07    0.015 -66340.666667
# 2022-11-12  298741.733333    0.004  2.676681e+07    0.015 -66592.933333
# ...                   ...      ...           ...      ...           ...
# 2023-12-27            NaN      NaN           NaN      NaN           NaN
# 2023-12-28            NaN      NaN           NaN      NaN           NaN
# 2023-12-29            NaN      NaN           NaN      NaN           NaN
# 2023-12-30            NaN      NaN           NaN      NaN           NaN
# 2023-12-31            NaN      NaN           NaN      NaN           NaN
#
#             BC_var
# 2022-11-08   0.386
# 2022-11-09   0.385
# 2022-11-10   0.383
# 2022-11-11   0.382
# 2022-11-12   0.380
# ...            ...
# 2023-12-27     NaN
# 2023-12-28     NaN
# 2023-12-29     NaN
# 2023-12-30     NaN
# 2023-12-31     NaN
#
# [419 rows x 15 columns]

# %%
# Eliminar filas donde 'columna_objetivo' es NaN
df_indicadores_D = df_indicadores_D.dropna(subset=['VTI_value'])
# Reemplazar NaN con el valor anterior en cada columna
#df_indicadores_D = df_indicadores_D.fillna(method='ffill') obj.ffill()
df_indicadores_D = df_indicadores_D.ffill()
df_indicadores_D
# Out:
#             VTI_value  cierre_anterior  pct_change_1d  pct_change_5d  \
# 2022-11-08     191.66              NaN            NaN            NaN
# 2022-11-09     187.53           191.66      -2.154858            NaN
# 2022-11-10     198.14           187.53       5.657761            NaN
# 2022-11-11     200.16           198.14       1.019481            NaN
# 2022-11-14     198.35           200.16      -0.904277            NaN
# ...               ...              ...            ...            ...
# 2023-12-22     236.63           236.09       0.228726       0.560962
# 2023-12-26     237.80           236.63       0.494443       0.622012
# 2023-12-27     238.25           237.80       0.189235       0.079812
# 2023-12-28     238.13           238.25      -0.050367       1.543644
# 2023-12-29     237.22           238.13      -0.382144       0.478631
#
#             pct_change_10d  TPM_value  TPM_var  TDES_value  TDES_var  \
# 2022-11-08             NaN       3.83      0.0    3.576667    -0.093
# 2022-11-09             NaN       3.83      0.0    3.573333    -0.093
# 2022-11-10             NaN       3.83      0.0    3.570000    -0.093
# 2022-11-11             NaN       3.83      0.0    3.566667    -0.093
# 2022-11-14             NaN       3.83      0.0    3.556667    -0.094
# ...                    ...        ...      ...         ...       ...
# 2023-12-22        3.399607       5.33      0.0    3.700000    -0.174
# 2023-12-26        3.485791       5.33      0.0    3.700000    -0.174
# 2023-12-27        3.290558       5.33      0.0    3.700000    -0.174
# 2023-12-28        1.660690       5.33      0.0    3.700000    -0.174
# 2023-12-29        0.674787       5.33      0.0    3.700000    -0.174
#
#                 IPC_value  IPC_var     PIB_value  PIB_var      BC_value  \
# 2022-11-08  298689.466667    0.004  2.675035e+07    0.015 -65583.866667
# 2022-11-09  298702.533333    0.004  2.675446e+07    0.015 -65836.133333
# 2022-11-10  298715.600000    0.004  2.675858e+07    0.015 -66088.400000
# 2022-11-11  298728.666667    0.004  2.676269e+07    0.015 -66340.666667
# 2022-11-14  298767.866667    0.004  2.677503e+07    0.015 -67097.466667
# ...                   ...      ...           ...      ...           ...
# 2023-12-22  307917.000000    0.003  2.776828e+07    0.021 -64048.066667
# 2023-12-26  307917.000000    0.003  2.776828e+07    0.021 -64048.066667
# 2023-12-27  307917.000000    0.003  2.776828e+07    0.021 -64048.066667
# 2023-12-28  307917.000000    0.003  2.776828e+07    0.021 -64048.066667
# 2023-12-29  307917.000000    0.003  2.776828e+07    0.021 -64048.066667
#
#             BC_var
# 2022-11-08   0.386
# 2022-11-09   0.385
# 2022-11-10   0.383
# 2022-11-11   0.382
# 2022-11-14   0.377
# ...            ...
# 2023-12-22   0.162
# 2023-12-26   0.162
# 2023-12-27   0.162
# 2023-12-28   0.162
# 2023-12-29   0.162
#
# [287 rows x 15 columns]

# %%
df_indicadores_D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 287 entries, 2022-11-08 to 2023-12-29
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VTI_value        287 non-null    float64
#  1   cierre_anterior  286 non-null    float64
#  2   pct_change_1d    286 non-null    float64
#  3   pct_change_5d    282 non-null    float64
#  4   pct_change_10d   277 non-null    float64
#  5   TPM_value        287 non-null    float64
#  6   TPM_var          287 non-null    float64
#  7   TDES_value       287 non-null    float64
#  8   TDES_var         287 non-null    float64
#  9   IPC_value        287 non-null    float64
#  10  IPC_var          287 non-null    float64
#  11  PIB_value        287 non-null    float64
#  12  PIB_var          287 non-null    float64
#  13  BC_value         287 non-null    float64
#  14  BC_var           287 non-null    float64
# dtypes: float64(15)
# memory usage: 35.9+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Calcular la matriz de correlación
matriz_correlacion = df_indicadores_D.corr()
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm')
plt.show()

# %%
guardar_csv(df_indicadores_D,"../data/processed/total_data.csv")
